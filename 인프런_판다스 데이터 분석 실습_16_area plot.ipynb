# %% [markdown]
# # area plot 산점도
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline
# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.517299  0.994332  0.307701  0.400721
# 1  0.017957  0.084413  0.874806  0.393801
# 2  0.241142  0.332616  0.844993  0.814993
# 3  0.491566  0.604955  0.386188  0.009358
# 4  0.528882  0.441700  0.204236  0.166867
# 5  0.792111  0.228899  0.570566  0.532639
# 6  0.842097  0.292713  0.347872  0.465145
# 7  0.265973  0.813560  0.556609  0.363065
# 8  0.527192  0.195168  0.036954  0.602412
# 9  0.546133  0.426672  0.404014  0.110781

# %%
 df.plot.area(grid=True)

# %%
 df.plot.area(stacked=False, grid=True)

# %%
df.plot()

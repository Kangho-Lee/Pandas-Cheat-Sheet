# %%
# %python

ACCESS_KEY_ID = "AKIAI4OT7Y4GOOXC7OHQ"
SECRET_ACCESS_KEY = "JgpQyB6IqpmjjMu6cdtqQkvHTV75nYdI6SM3UXXL"
ENCODED_SECRET_ACCESS_KEY = SECRET_ACCESS_KEY.replace("/", "%2F")

dbutils.fs.mount("s3a://%s:%s@edwith-pyspark-dataset" % (ACCESS_KEY_ID, ENCODED_SECRET_ACCESS_KEY), "/mnt/us-carrier-dataset")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: True</div>

# %%
# %python

display(dbutils.fs.ls("/mnt/us-carrier-dataset"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/us-carrier-dataset/1987.csv</td><td>1987.csv</td><td>127162942</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1988.csv</td><td>1988.csv</td><td>501039472</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1989.csv</td><td>1989.csv</td><td>486518821</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1990.csv</td><td>1990.csv</td><td>509194687</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1991.csv</td><td>1991.csv</td><td>491210093</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1992.csv</td><td>1992.csv</td><td>492313731</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1993.csv</td><td>1993.csv</td><td>490753652</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1994.csv</td><td>1994.csv</td><td>501558665</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1995.csv</td><td>1995.csv</td><td>530751568</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1996.csv</td><td>1996.csv</td><td>533922363</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1997.csv</td><td>1997.csv</td><td>540347861</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1998.csv</td><td>1998.csv</td><td>538432875</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/1999.csv</td><td>1999.csv</td><td>552926022</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2000.csv</td><td>2000.csv</td><td>570151613</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2001.csv</td><td>2001.csv</td><td>600411462</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2002.csv</td><td>2002.csv</td><td>530507013</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2003.csv</td><td>2003.csv</td><td>626745242</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2004.csv</td><td>2004.csv</td><td>669879113</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2005.csv</td><td>2005.csv</td><td>671027265</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2006.csv</td><td>2006.csv</td><td>672068096</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2007.csv</td><td>2007.csv</td><td>702878193</td></tr><tr><td>dbfs:/mnt/us-carrier-dataset/2008.csv</td><td>2008.csv</td><td>689413344</td></tr></tbody></table></div>

# %%
# %python

from pyspark.sql import SparkSession

spark = SparkSession \
  .builder \
  .appName("Spark EDA example on us aircraft data ") \
  .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python

raw_df = spark.read.csv("/mnt/us-carrier-dataset", header = 'True', inferSchema='True')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python

raw_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Year: integer (nullable = true)
# -- Month: integer (nullable = true)
# -- DayofMonth: integer (nullable = true)
# -- DayOfWeek: integer (nullable = true)
# -- DepTime: string (nullable = true)
# -- CRSDepTime: integer (nullable = true)
# -- ArrTime: string (nullable = true)
# -- CRSArrTime: integer (nullable = true)
# -- UniqueCarrier: string (nullable = true)
# -- FlightNum: integer (nullable = true)
# -- TailNum: string (nullable = true)
# -- ActualElapsedTime: string (nullable = true)
# -- CRSElapsedTime: string (nullable = true)
# -- AirTime: string (nullable = true)
# -- ArrDelay: string (nullable = true)
# -- DepDelay: string (nullable = true)
# -- Origin: string (nullable = true)
# -- Dest: string (nullable = true)
# -- Distance: string (nullable = true)
# -- TaxiIn: string (nullable = true)
# -- TaxiOut: string (nullable = true)
# -- Cancelled: integer (nullable = true)
# -- CancellationCode: string (nullable = true)
# -- Diverted: integer (nullable = true)
# -- CarrierDelay: string (nullable = true)
# -- WeatherDelay: string (nullable = true)
# -- NASDelay: string (nullable = true)
# -- SecurityDelay: string (nullable = true)
# -- LateAircraftDelay: string (nullable = true)
#
# </div>

# %%
# %python

# 개수
raw_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: 123534969</div>

# %%
# %python

raw_df.show(30)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+----------+---------+-------+----------+-------+----------+-------------+---------+-------+-----------------+--------------+-------+--------+--------+------+----+--------+------+-------+---------+----------------+--------+------------+------------+--------+-------------+-----------------+
# Year|Month|DayofMonth|DayOfWeek|DepTime|CRSDepTime|ArrTime|CRSArrTime|UniqueCarrier|FlightNum|TailNum|ActualElapsedTime|CRSElapsedTime|AirTime|ArrDelay|DepDelay|Origin|Dest|Distance|TaxiIn|TaxiOut|Cancelled|CancellationCode|Diverted|CarrierDelay|WeatherDelay|NASDelay|SecurityDelay|LateAircraftDelay|
# +----+-----+----------+---------+-------+----------+-------+----------+-------------+---------+-------+-----------------+--------------+-------+--------+--------+------+----+--------+------+-------+---------+----------------+--------+------------+------------+--------+-------------+-----------------+
# 1988|    1|         9|        6|   1348|      1331|   1458|      1435|           PI|      942|     NA|               70|            64|     NA|      23|      17|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        10|        7|   1334|      1331|   1443|      1435|           PI|      942|     NA|               69|            64|     NA|       8|       3|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        11|        1|   1446|      1331|   1553|      1435|           PI|      942|     NA|               67|            64|     NA|      78|      75|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        12|        2|   1334|      1331|   1438|      1435|           PI|      942|     NA|               64|            64|     NA|       3|       3|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        13|        3|   1341|      1331|   1503|      1435|           PI|      942|     NA|               82|            64|     NA|      28|      10|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        14|        4|   1332|      1331|   1447|      1435|           PI|      942|     NA|               75|            64|     NA|      12|       1|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        15|        5|   1331|      1331|   1434|      1435|           PI|      942|     NA|               63|            64|     NA|      -1|       0|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        16|        6|   1327|      1331|   1427|      1435|           PI|      942|     NA|               60|            64|     NA|      -8|      -4|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        17|        7|   1331|      1331|   1440|      1435|           PI|      942|     NA|               69|            64|     NA|       5|       0|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        18|        1|   1349|      1331|   1519|      1435|           PI|      942|     NA|               90|            64|     NA|      44|      18|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        19|        2|   1337|      1331|   1438|      1435|           PI|      942|     NA|               61|            64|     NA|       3|       6|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        20|        3|   1337|      1331|   1452|      1435|           PI|      942|     NA|               75|            64|     NA|      17|       6|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        21|        4|   1330|      1331|   1459|      1435|           PI|      942|     NA|               89|            64|     NA|      24|      -1|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        22|        5|   1331|      1331|   1434|      1435|           PI|      942|     NA|               63|            64|     NA|      -1|       0|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        23|        6|   1333|      1331|   1436|      1435|           PI|      942|     NA|               63|            64|     NA|       1|       2|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        24|        7|   1328|      1331|   1430|      1435|           PI|      942|     NA|               62|            64|     NA|      -5|      -3|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        25|        1|   1330|      1331|   1444|      1435|           PI|      942|     NA|               74|            64|     NA|       9|      -1|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        26|        2|   1407|      1331|   1518|      1435|           PI|      942|     NA|               71|            64|     NA|      43|      36|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        27|        3|   1332|      1331|   1445|      1435|           PI|      942|     NA|               73|            64|     NA|      10|       1|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        28|        4|   1331|      1331|   1438|      1435|           PI|      942|     NA|               67|            64|     NA|       3|       0|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        29|        5|   1339|      1331|   1442|      1435|           PI|      942|     NA|               63|            64|     NA|       7|       8|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        30|        6|   1332|      1331|   1435|      1435|           PI|      942|     NA|               63|            64|     NA|       0|       1|   SYR| BWI|     273|    NA|     NA|        0|              NA|       0|          NA|          NA|      NA|           NA|               NA|
# 1988|    1|        31|        7|   1329|      1331|   1434|      1435|           PI|      942|     NA|               65|            64|     NA|

# %%
# %python

display(raw_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Month</th><th>DayofMonth</th><th>DayOfWeek</th><th>DepTime</th><th>CRSDepTime</th><th>ArrTime</th><th>CRSArrTime</th><th>UniqueCarrier</th><th>FlightNum</th><th>TailNum</th><th>ActualElapsedTime</th><th>CRSElapsedTime</th><th>AirTime</th><th>ArrDelay</th><th>DepDelay</th><th>Origin</th><th>Dest</th><th>Distance</th><th>TaxiIn</th><th>TaxiOut</th><th>Cancelled</th><th>CancellationCode</th><th>Diverted</th><th>CarrierDelay</th><th>WeatherDelay</th><th>NASDelay</th><th>SecurityDelay</th><th>LateAircraftDelay</th></tr></thead><tbody><tr><td>1988</td><td>1</td><td>9</td><td>6</td><td>1348</td><td>1331</td><td>1458</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>70</td><td>64</td><td>NA</td><td>23</td><td>17</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>10</td><td>7</td><td>1334</td><td>1331</td><td>1443</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>69</td><td>64</td><td>NA</td><td>8</td><td>3</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>11</td><td>1</td><td>1446</td><td>1331</td><td>1553</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>67</td><td>64</td><td>NA</td><td>78</td><td>75</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>12</td><td>2</td><td>1334</td><td>1331</td><td>1438</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>64</td><td>64</td><td>NA</td><td>3</td><td>3</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>13</td><td>3</td><td>1341</td><td>1331</td><td>1503</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>82</td><td>64</td><td>NA</td><td>28</td><td>10</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>14</td><td>4</td><td>1332</td><td>1331</td><td>1447</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>75</td><td>64</td><td>NA</td><td>12</td><td>1</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>15</td><td>5</td><td>1331</td><td>1331</td><td>1434</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>63</td><td>64</td><td>NA</td><td>-1</td><td>0</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>16</td><td>6</td><td>1327</td><td>1331</td><td>1427</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>60</td><td>64</td><td>NA</td><td>-8</td><td>-4</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>17</td><td>7</td><td>1331</td><td>1331</td><td>1440</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>69</td><td>64</td><td>NA</td><td>5</td><td>0</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>1988</td><td>1</td><td>18</td><td>1</td><td>1349</td><td>1331</td><td>1519</td><td>1435</td><td>PI</td><td>942</td><td>NA</td><td>90</td><td>64</td><td>NA</td><td>44</td><td>18</td><td>SYR</td><td>BWI</td><td>273</td><td>NA</td><td>NA</td><td>0</td><td>NA</td><td>0</td><td>NA</td><td>NA</td> ...

# %%
# %python

from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType, IntegerType, StringType

# NA값을 null로 변경하기
def cleanString(value):
  if (value == None) or (value == 'NA'):
    return None
  else:
    value

# string으로 설정된 숫자를 Integer로 변경
def stringToInteger(value):
  if value == 'NA':
    return None
  else:
    return int(value)

# Integer값을 Boolean으로 변경
def integerToBoolean(value):
  if value == 0:
    return False 
  else:
    return True
  
cleanStrFunction = udf(stringToInteger, IntegerType())
cleanIntegerFunction = udf(integerToBoolean, BooleanType())
cleanStringFunction = udf(cleanString, StringType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python

us_carrier_df = raw_df \
    .drop(
      # 사용하지 않을 column 삭제
      'DepTime', 'CRSDepTime', 'ArrTime', 'CRSArrTime', 'AirTime', 'ArrDelay', 'DepDelay', 'TaxiIn', 'TaxiOut', 'CancellationCode', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay') \
    .withColumn(
      # 'NA' 항목 null로 변경하고 Integer 형으로 변경
      'ActualElapsedTime', cleanStrFunction('ActualElapsedTime')) \
    .withColumn(
      # 'NA' 항목 null로 변경하고 Integer 형으로 변경
      'CRSElapsedTime', cleanStrFunction('CRSElapsedTime')) \
    .withColumn(
      # 'NA' 항목 null로 변경하고 Integer 형으로 변경
      'Distance', cleanStrFunction('Distance')) \
    .withColumn(
      # 'NA' 항목 null로 변경하고 Boolean 형으로 변경
      'Cancelled', cleanIntegerFunction('Cancelled')) \
    .withColumn(
      # 'NA' 항목 null로 변경하고 Boolean 형으로 변경
      'Diverted', cleanIntegerFunction('Diverted'))

us_carrier_df.printSchema()
us_carrier_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Year: integer (nullable = true)
# -- Month: integer (nullable = true)
# -- DayofMonth: integer (nullable = true)
# -- DayOfWeek: integer (nullable = true)
# -- UniqueCarrier: string (nullable = true)
# -- FlightNum: integer (nullable = true)
# -- TailNum: string (nullable = true)
# -- ActualElapsedTime: integer (nullable = true)
# -- CRSElapsedTime: integer (nullable = true)
# -- Origin: string (nullable = true)
# -- Dest: string (nullable = true)
# -- Distance: integer (nullable = true)
# -- Cancelled: boolean (nullable = true)
# -- Diverted: boolean (nullable = true)
#
# +----+-----+----------+---------+-------------+---------+-------+-----------------+--------------+------+----+--------+---------+--------+
# Year|Month|DayofMonth|DayOfWeek|UniqueCarrier|FlightNum|TailNum|ActualElapsedTime|CRSElapsedTime|Origin|Dest|Distance|Cancelled|Diverted|
# +----+-----+----------+---------+-------------+---------+-------+-----------------+--------------+------+----+--------+---------+--------+
# 1988|    1|         9|        6|           PI|      942|     NA|               70|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        10|        7|           PI|      942|     NA|               69|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        11|        1|           PI|      942|     NA|               67|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        12|        2|           PI|      942|     NA|               64|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        13|        3|           PI|      942|     NA|               82|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        14|        4|           PI|      942|     NA|               75|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        15|        5|           PI|      942|     NA|               63|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        16|        6|           PI|      942|     NA|               60|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        17|        7|           PI|      942|     NA|               69|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        18|        1|           PI|      942|     NA|               90|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        19|        2|           PI|      942|     NA|               61|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        20|        3|           PI|      942|     NA|               75|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        21|        4|           PI|      942|     NA|               89|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        22|        5|           PI|      942|     NA|               63|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        23|        6|           PI|      942|     NA|               63|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        24|        7|           PI|      942|     NA|               62|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        25|        1|           PI|      942|     NA|               74|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        26|        2|           PI|      942|     NA|               71|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        27|        3|           PI|      942|     NA|               73|            64|   SYR| BWI|     273|    false|   false|
# 1988|    1|        28|        4|           PI|      942|     NA|               67|            64|   SYR| BWI|     273|    false|   false|
# +----+-----+----------+---------+-------------+---------+-------+-----------------+--------------+------+----+--------+---------+--------+
# only showing top 20 rows
#
# </div>

# %%
# %python

# 추후 자주 사용할 자료이므로 클러스터 메모리 상에 남겨 두고 삭제하지 않도록 합니다.
us_carrier_df.cache()

# 추후 SQL문 형태로 질의할 때 사용하기 위해 클렌징이 끝난 Dataframe을 전역 임시 뷰로 지정합니다.
us_carrier_df.createGlobalTempView("us_carrier")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python

# `UniqueCarrier` 항목만을 가지는 DataFrame
carriers_only_df = us_carrier_df.select("UniqueCarrier")
carriers_only_distinct_df = carriers_only_df.distinct()

carriers_only_distinct_df.show(50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# UniqueCarrier|
# +-------------+
#            UA|
#            EA|
#            PI|
#            PS|
#            AA|
#            NW|
#            EV|
#            B6|
#            HP|
#            TW|
#            DL|
#            OO|
#            F9|
#            YV|
#            TZ|
#            US|
#            AQ|
#            MQ|
#            OH|
#            HA|
#        ML (1)|
#            XE|
#            DH|
#            AS|
#            CO|
#            FL|
#        PA (1)|
#            WN|
#            9E|
# +-------------+
#
# </div>

# %%
# %python
spark.sql("SELECT DISTINCT UniqueCarrier FROM global_temp.us_carrier").show(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# UniqueCarrier|
# +-------------+
#            UA|
#            EA|
#            PI|
#            PS|
#            AA|
#            NW|
#            EV|
#            B6|
#            HP|
#            TW|
#            DL|
#            OO|
#            F9|
#            YV|
#            TZ|
#            US|
#            AQ|
#            MQ|
#            OH|
#            HA|
# +-------------+
# only showing top 20 rows
#
# </div>

# %%
# %python
from pyspark.sql.functions import col

# us_carrier_df.filter(col('UniqueCarrier') == 'DL').show(10)
# us_carrier_df.filter(col('Year') == 1990).show()
# us_carrier_df.filter(col('UniqueCarrier') == 'DL').filter(col('Year') == 1990).show(20)
# us_carrier_df\
#   .filter((col('UniqueCarrier') == 'DL') & (col('Year') == 1990))\
#   .show(10)

# spark.sql("SELECT * FROM global_temp.us_carrier WHERE UniqueCarrier == 'DL' AND Year == 1990").show(10)
us_carrier_df.filter((col('UniqueCarrier') == 'DL') & (col('Year') == 1990))\
  .count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 824062</div>

# %%
# %python

from pyspark.sql.functions import min, mean, max

us_carrier_df.select(mean('distance'), min('distance'), max('distance')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------+-------------+
#     avg(distance)|min(distance)|max(distance)|
# +-----------------+-------------+-------------+
# 701.6985307716058|            0|         4983|
# +-----------------+-------------+-------------+
#
# </div>

# %%
# %python
# us_carrier_df.filter(col('distance') == 0).show()
# us_carrier_df.filter(col('distance') == 4983).show()
us_carrier_df.describe('distance').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+
# summary|         distance|
# +-------+-----------------+
#   count|        123332969|
#    mean|701.6985307716058|
#  stddev|551.2531700322843|
#     min|                0|
#     max|             4983|
# +-------+-----------------+
#
# </div>

# %%
# %python

line_distinct_1987_df = us_carrier_df.filter(col('Year') == 1987) \
  .select('Origin', 'Dest') \
  .distinct()

line_distinct_1987_df.orderBy('Origin', 'Dest').show()

us_carrier_df.filter(col('Year') == 1987) \
  .select('Origin', 'Dest') \
  .distinct() \
  .count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+
# Origin|Dest|
# +------+----+
#    ABE| ATL|
#    ABE| AVP|
#    ABE| DTW|
#    ABE| MDT|
#    ABE| ORD|
#    ABE| PHL|
#    ABE| PIT|
#    ABQ| AMA|
#    ABQ| DAL|
#    ABQ| DEN|
#    ABQ| DFW|
#    ABQ| ELP|
#    ABQ| IAH|
#    ABQ| LAS|
#    ABQ| LAX|
#    ABQ| LBB|
#    ABQ| MAF|
#    ABQ| MCI|
#    ABQ| ORD|
#    ABQ| PHX|
# +------+----+
# only showing top 20 rows
#
# Out[40]: 3464</div>

# %%
# %python

us_carrier_df.filter(col('Year') == 1993) \
  .select('Origin', 'Dest') \
  .distinct() \
  .count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: 3425</div>

# %%
# %python

spark.sql("SELECT COUNT(DISTINCT(Origin, Dest)) AS COUNT FROM global_temp.us_carrier WHERE Year = 1987").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+
# COUNT|
# +-----+
#  3464|
# +-----+
#
# </div>

# %%
# %python

from pyspark.sql.functions import desc

# dest_by_arrival_df = us_carrier_df.groupby('Dest').count()
# dest_by_arrival_df.orderBy(desc('count')).show()
spark.sql("SELECT Dest, COUNT(*) FROM global_temp.us_carrier GROUP BY Dest ORDER BY Dest").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------+
# Dest|count(1)|
# +----+--------+
#  ABE|  121986|
#  ABI|   21706|
#  ABQ|  757834|
#  ABY|    7969|
#  ACK|    1825|
#  ACT|   21059|
#  ACV|   23587|
#  ACY|    8705|
#  ADK|     589|
#  ADQ|   10320|
#  AEX|   17244|
#  AGS|   52964|
#  AKN|    6001|
#  ALB|  291304|
#  ALO|    1568|
#  AMA|  131548|
#  ANC|  394971|
#  ANI|     472|
#  APF|    3953|
#  ASE|   14209|
# +----+--------+
# only showing top 20 rows
#
# </div>

# %%
# %python

display(us_carrier_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Month</th><th>DayofMonth</th><th>DayOfWeek</th><th>UniqueCarrier</th><th>FlightNum</th><th>TailNum</th><th>ActualElapsedTime</th><th>CRSElapsedTime</th><th>Origin</th><th>Dest</th><th>Distance</th><th>Cancelled</th><th>Diverted</th></tr></thead><tbody><tr><td>1988</td><td>1</td><td>9</td><td>6</td><td>PI</td><td>942</td><td>NA</td><td>70</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>10</td><td>7</td><td>PI</td><td>942</td><td>NA</td><td>69</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>11</td><td>1</td><td>PI</td><td>942</td><td>NA</td><td>67</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>12</td><td>2</td><td>PI</td><td>942</td><td>NA</td><td>64</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>13</td><td>3</td><td>PI</td><td>942</td><td>NA</td><td>82</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>14</td><td>4</td><td>PI</td><td>942</td><td>NA</td><td>75</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>15</td><td>5</td><td>PI</td><td>942</td><td>NA</td><td>63</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>16</td><td>6</td><td>PI</td><td>942</td><td>NA</td><td>60</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>17</td><td>7</td><td>PI</td><td>942</td><td>NA</td><td>69</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>18</td><td>1</td><td>PI</td><td>942</td><td>NA</td><td>90</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>19</td><td>2</td><td>PI</td><td>942</td><td>NA</td><td>61</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>20</td><td>3</td><td>PI</td><td>942</td><td>NA</td><td>75</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>21</td><td>4</td><td>PI</td><td>942</td><td>NA</td><td>89</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>22</td><td>5</td><td>PI</td><td>942</td><td>NA</td><td>63</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>23</td><td>6</td><td>PI</td><td>942</td><td>NA</td><td>63</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>24</td><td>7</td><td>PI</td><td>942</td><td>NA</td><td>62</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>25</td><td>1</td><td>PI</td><td>942</td><td>NA</td><td>74</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>26</td><td>2</td><td>PI</td><td>942</td><td>NA</td><td>71</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>27</td><td>3</td><td>PI</td><td>942</td><td>NA</td><td>73</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>28</td><td>4</td><td>PI</td><td>942</td><td>NA</td><td>67</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td>false</td></tr><tr><td>1988</td><td>1</td><td>29</td><td>5</td><td>PI</td><td>942</td><td>NA</td><td>63</td><td>64</td><td>SYR</td><td>BWI</td><td>273</td><td>false</td><td ...

# %%
# %python

actual_elapsed_df = us_carrier_df.groupBy('Origin', 'Dest').mean('ActualElapsedTime')
expected_elapsed_df = us_carrier_df.groupBy('Origin', 'Dest').min('CRSElapsedTime')

joined_df = actual_elapsed_df\
  .join(expected_elapsed_df, (actual_elapsed_df['Origin'] == expected_elapsed_df['Origin']) & (actual_elapsed_df['Dest'] == expected_elapsed_df['Dest']))

joined_aligned_df = joined_df\
  .select(actual_elapsed_df['Origin'], actual_elapsed_df['Dest'], 'avg(ActualElapsedTime)', col('min(CRSElapsedTime)').alias('CRSElapsedTime'))

joined_aligned_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+----------------------+--------------+
# Origin|Dest|avg(ActualElapsedTime)|CRSElapsedTime|
# +------+----+----------------------+--------------+
#    ADK| AKN|    128.50135501355012|           117|
#    ATL| GSP|     51.52835697846175|            37|
#    AVP| JFK|     71.47058823529412|            60|
#    BDL| SLC|     310.3319502074689|           305|
#    BFL| SAN|    54.772887323943664|            55|
#    BOI| SBA|    220.92424242424244|           191|
#    BQN| MCO|    162.22651933701658|           125|
#    BUR| MRY|                  null|            70|
#    CLE| SJU|     256.5263653483992|           249|
#    DAY| JFK|    105.62045760430686|            90|
#    DSM| EWR|     153.5728155339806|           135|
#    EWR| STT|    242.35271128480704|           219|
#    FSD| ATL|     148.8791390728477|           145|
#    GRR| PIT|      65.0678077682686|            50|
#    GSP| PIT|     76.87394957983193|            55|
#    HTS| MCN|                  95.0|            75|
#    ICT| LIT|     60.18518518518518|            61|
#    LAS| LIT|    173.08053923263049|           170|
#    LAX| OXR|    30.822375511963784|            26|
#    LNK| OMA|    25.044642857142858|            24|
# +------+----+----------------------+--------------+
# only showing top 20 rows
#
# </div>

# %%
# %python

from pyspark.sql.functions import abs

difference_df = joined_aligned_df\
  .select('Origin', 'Dest', abs(col('avg(ActualElapsedTime)') - col('CRSElapsedTime')))

difference_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+----------------------------------------------+
# Origin|Dest|abs((avg(ActualElapsedTime) - CRSElapsedTime))|
# +------+----+----------------------------------------------+
#    ADK| AKN|                            11.501355013550125|
#    ATL| GSP|                            14.528356978461751|
#    AVP| JFK|                            11.470588235294116|
#    BDL| SLC|                            5.3319502074688785|
#    BFL| SAN|                           0.22711267605633623|
#    BOI| SBA|                            29.924242424242436|
#    BQN| MCO|                             37.22651933701658|
#    BUR| MRY|                                          null|
#    CLE| SJU|                             7.526365348399224|
#    DAY| JFK|                            15.620457604306864|
#    DSM| EWR|                            18.572815533980588|
#    EWR| STT|                            23.352711284807043|
#    FSD| ATL|                            3.8791390728476927|
#    GRR| PIT|                            15.067807768268594|
#    GSP| PIT|                             21.87394957983193|
#    HTS| MCN|                                          20.0|
#    ICT| LIT|                            0.8148148148148167|
#    LAS| LIT|                            3.0805392326304855|
#    LAX| OXR|                             4.822375511963784|
#    LNK| OMA|                            1.0446428571428577|
# +------+----+----------------------------------------------+
# only showing top 20 rows
#
# </div>

# %%
# %python

difference_df\
  .select('Origin', 'Dest', col('abs((avg(ActualElapsedTime) - CRSElapsedTime))')\
  .alias('difference'))\
  .orderBy(desc('difference'))\
  .show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+------------------+
# Origin|Dest|        difference|
# +------+----+------------------+
#    JFK| AUS|1476.2607558139534|
#    VPS| DHN|             512.0|
#    PHX| JFK| 444.1817228226319|
#    LIH| LAX|396.62511291779583|
#    BOS| LAX| 319.5572305229456|
#    ORD| HNL|318.56579033632727|
#    PHX| DCA|315.28186109238027|
#    SEA| BOS| 314.1135195080149|
#    DFW| OGG|308.03667563930014|
#    SNA| ORD|307.26533535848665|
#    HNL| ORD|305.55223880597015|
#    DFW| HNL| 299.7765151515151|
#    DEN| HNL|299.72057646116895|
#    JFK| SAN|292.30877054717405|
#    OAK| IAD| 291.5955174841586|
#    LGB| FLL|289.18823529411765|
#    LAX| BOS|283.17967048310527|
#    BOS| LAS| 278.0052805280528|
#    SBA| DFW| 277.7184615384615|
#    BUR| DFW|276.51984257133483|
# +------+----+------------------+
# only showing top 20 rows
#
# </div>

# %%
# %python

count_per_origin_df = us_carrier_df\
  .groupBy('Origin')\
  .count()\
  .select('Origin', col('count').alias('total'))\
  .orderBy('Origin')

count_per_origin_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+------+
# Origin| total|
# +------+------+
#    ABE|122976|
#    ABI| 21713|
#    ABQ|760324|
#    ABY|  8035|
#    ACK|  1812|
#    ACT| 21081|
#    ACV| 23782|
#    ACY|  8798|
#    ADK|   589|
#    ADQ| 10327|
#    AEX| 17245|
#    AGS| 53378|
#    AKN|  6005|
#    ALB|292764|
#    ALO|  1564|
#    AMA|132477|
#    ANC|395392|
#    ANI|   475|
#    APF|  4074|
#    ASE| 14345|
# +------+------+
# only showing top 20 rows
#
# </div>

# %%
# %python

count_per_origin_dest_df = us_carrier_df\
  .groupBy('Origin', 'Dest')\
  .count()\
  .orderBy('Origin', 'Dest')

count_per_origin_dest_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-----+
# Origin|Dest|count|
# +------+----+-----+
#    ABE| ALB|    2|
#    ABE| ATL|16541|
#    ABE| AVP| 1627|
#    ABE| AZO|    1|
#    ABE| BDL|    1|
#    ABE| BHM|    1|
#    ABE| BWI| 2559|
#    ABE| CLE| 5860|
#    ABE| CLT| 7261|
#    ABE| CVG| 6881|
#    ABE| DCA|  395|
#    ABE| DTW|17738|
#    ABE| FWA|    2|
#    ABE| GRR|    1|
#    ABE| HPN|   99|
#    ABE| IAD| 2075|
#    ABE| IND|    1|
#    ABE| JFK|   10|
#    ABE| LGA|  216|
#    ABE| MCO| 1868|
# +------+----+-----+
# only showing top 20 rows
#
# </div>

# %%
# %python

joined_df = count_per_origin_df\
  .join(count_per_origin_dest_df, count_per_origin_df['Origin'] == count_per_origin_dest_df['Origin'])\
  .drop(count_per_origin_df['Origin'])

joined_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+------+----+-----+
# total|Origin|Dest|count|
# +-----+------+----+-----+
# 26486|   BGM| ATL|  593|
# 26486|   BGM| BWI| 3052|
# 26486|   BGM| CVG| 2415|
# 26486|   BGM| DTW| 1447|
# 26486|   BGM| ELM|  787|
# 26486|   BGM| IAD| 1646|
# 26486|   BGM| ITH|  304|
# 26486|   BGM| JFK|   18|
# 26486|   BGM| PHL|  244|
# 26486|   BGM| PIT|15980|
#  4924|   DLG| ADQ|   27|
#  4924|   DLG| AKN|  432|
#  4924|   DLG| ANC| 4465|
#   290|   INL| MSP|  290|
#  2883|   PSE| EWR|  657|
#  2883|   PSE| FLL|  101|
#  2883|   PSE| IAD|    1|
#  2883|   PSE| JFK| 1344|
#  2883|   PSE| MCO|  563|
#  2883|   PSE| MIA|  217|
# +-----+------+----+-----+
# only showing top 20 rows
#
# </div>

# %%
# %python

# 표시 순서 변경 + (Origin, Dest) 순으로 정렬.
joined_reordered_df = joined_df\
  .select('Origin', 'Dest', 'count', 'total')\
  .orderBy('Origin', 'Dest')

joined_reordered_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-----+------+
# Origin|Dest|count| total|
# +------+----+-----+------+
#    ABE| ALB|    2|122976|
#    ABE| ATL|16541|122976|
#    ABE| AVP| 1627|122976|
#    ABE| AZO|    1|122976|
#    ABE| BDL|    1|122976|
#    ABE| BHM|    1|122976|
#    ABE| BWI| 2559|122976|
#    ABE| CLE| 5860|122976|
#    ABE| CLT| 7261|122976|
#    ABE| CVG| 6881|122976|
#    ABE| DCA|  395|122976|
#    ABE| DTW|17738|122976|
#    ABE| FWA|    2|122976|
#    ABE| GRR|    1|122976|
#    ABE| HPN|   99|122976|
#    ABE| IAD| 2075|122976|
#    ABE| IND|    1|122976|
#    ABE| JFK|   10|122976|
#    ABE| LGA|  216|122976|
#    ABE| MCO| 1868|122976|
# +------+----+-----+------+
# only showing top 20 rows
#
# </div>

# %%
# %python

from pyspark.sql.functions import round

origin_to_dest_rate = joined_reordered_df\
  .select('Origin', 'Dest', round((col('count') / col('total') * 100), 2).alias('rate'))

origin_to_dest_rate.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-----+
# Origin|Dest| rate|
# +------+----+-----+
#    ABE| ALB|  0.0|
#    ABE| ATL|13.45|
#    ABE| AVP| 1.32|
#    ABE| AZO|  0.0|
#    ABE| BDL|  0.0|
#    ABE| BHM|  0.0|
#    ABE| BWI| 2.08|
#    ABE| CLE| 4.77|
#    ABE| CLT|  5.9|
#    ABE| CVG|  5.6|
#    ABE| DCA| 0.32|
#    ABE| DTW|14.42|
#    ABE| FWA|  0.0|
#    ABE| GRR|  0.0|
#    ABE| HPN| 0.08|
#    ABE| IAD| 1.69|
#    ABE| IND|  0.0|
#    ABE| JFK| 0.01|
#    ABE| LGA| 0.18|
#    ABE| MCO| 1.52|
# +------+----+-----+
# only showing top 20 rows
#
# </div>

# %%
# %python

from pyspark.sql.functions import collect_list

depart_carriers = us_carrier_df.select('Origin', 'UniqueCarrier').distinct().groupBy('Origin').agg(collect_list('UniqueCarrier').alias('departs'))
# depart_carriers.show()
arrival_carriers = us_carrier_df.select('Dest', 'UniqueCarrier').distinct().groupBy('Dest').agg(collect_list('UniqueCarrier').alias('arrivals'))
# arrival_carriers.show()
departs_arrivals = depart_carriers.join(arrival_carriers, depart_carriers['Origin'] == arrival_carriers['Dest'])\
  .select(col('Origin').alias('airport'), 'departs', 'arrivals')
departs_arrivals.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------------------+
# airport|             departs|            arrivals|
# +-------+--------------------+--------------------+
#     BGM|[EV, PI, 9E, US, ...|[EV, PI, 9E, OO, ...|
#     DLG|                [AS]|                [AS]|
#     INL|                [9E]|                [9E]|
#     PSE|    [CO, B6, AA, EA]|[CO, B6, AA, EA, EV]|
#     MSY|[MQ, DL, ML (1), ...|[MQ, DL, ML (1), ...|
#     GEG|[UA, CO, F9, PS, ...|[UA, CO, F9, PS, ...|
#     BUR|[WN, AA, B6, US, ...|[WN, AA, B6, US, ...|
#     SNA|[CO, DL, WN, US, ...|[CO, DL, WN, US, ...|
#     GRB|[YV, 9E, OH, NW, ...|[YV, 9E, OH, NW, ...|
#     GTF|[UA, CO, OO, 9E, ...|[UA, CO, OO, 9E, ...|
#     IDA|[OO, XE, DL, AA, 9E]|[OO, XE, DL, AA, 9E]|
#     GRR|[US, EV, PI, OO, ...|[US, EV, PI, OO, ...|
#     LWB|        [AA, US, EV]|        [AA, US, EV]|
#     PVU|            [EV, OO]|            [EV, OO]|
#     EUG|[YV, PS, AA, OO, ...|[YV, PS, AA, OO, ...|
#     PSG|                [AS]|                [AS]|
#     GSO|[MQ, UA, 9E, EA, ...|[MQ, UA, 9E, EA, ...|
#     ISO|        [US, EV, PI]|        [US, EV, PI]|
#     MYR|[PI, OH, CO, DL, ...|[PI, OH, CO, DL, ...|
#     PVD|[EV, OH, DH, MQ, ...|[EV, OH, DH, MQ, ...|
# +-------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# %python

from pyspark.sql.functions import array_intersect, array_except

departs_arrivals_both = departs_arrivals.withColumn('both', array_intersect('departs', 'arrivals'))\
  .withColumn('arrival_only', array_except('arrivals', 'departs'))\
  .withColumn('depart_only', array_except('departs', 'arrivals'))\
  .drop('departs')\
  .drop('arrivals')

departs_arrivals_both.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+------------+-----------+
# airport|                both|arrival_only|depart_only|
# +-------+--------------------+------------+-----------+
#     BGM|[EV, PI, 9E, US, ...|        [OO]|         []|
#     DLG|                [AS]|          []|         []|
#     INL|                [9E]|          []|         []|
#     PSE|    [CO, B6, AA, EA]|        [EV]|         []|
#     MSY|[MQ, DL, ML (1), ...|          []|         []|
#     GEG|[UA, CO, F9, PS, ...|          []|         []|
#     BUR|[WN, AA, B6, US, ...|          []|         []|
#     SNA|[CO, DL, WN, US, ...|          []|         []|
#     GRB|[YV, 9E, OH, NW, ...|          []|         []|
#     GTF|[UA, CO, OO, 9E, ...|          []|         []|
#     IDA|[OO, XE, DL, AA, 9E]|          []|         []|
#     GRR|[US, EV, PI, OO, ...|          []|         []|
#     LWB|        [AA, US, EV]|          []|         []|
#     PVU|            [EV, OO]|          []|         []|
#     EUG|[YV, PS, AA, OO, ...|          []|         []|
#     PSG|                [AS]|          []|         []|
#     GSO|[MQ, UA, 9E, EA, ...|          []|         []|
#     ISO|        [US, EV, PI]|          []|         []|
#     MYR|[PI, OH, CO, DL, ...|          []|         []|
#     PVD|[EV, OH, DH, MQ, ...|          []|         []|
# +-------+--------------------+------------+-----------+
# only showing top 20 rows
#
# </div>

# %%
# %python

from pyspark.sql.functions import size

departs_arrivals_both.filter((size(departs_arrivals_both['arrival_only']) > 0) | (size(departs_arrivals_both['depart_only']) > 0)).show(100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+------------+-----------+
# airport|                both|arrival_only|depart_only|
# +-------+--------------------+------------+-----------+
#     BGM|[EV, PI, 9E, US, ...|        [OO]|         []|
#     PSE|    [CO, B6, AA, EA]|        [EV]|         []|
#     RFD|                [OO]|        [AA]|         []|
#     LNY|                [HA]|        [AA]|         []|
#     ORF|[TW, CO, EA, XE, ...|          []|   [PA (1)]|
#     SPN|                [CO]|          []|       [UA]|
#     MCN|                [EV]|        [OO]|       [OH]|
#     ATW|[EV, DH, YV, NW, ...|        [DL]|         []|
#     SBN|[YV, 9E, US, HP, ...|        [AA]|         []|
#     MKC|                [OO]|        [AA]|         []|
#     LAS|[TW, WN, HA, XE, ...|        [OH]|         []|
#     MKK|                [HA]|          []|       [AA]|
#     ALB|[EA, MQ, UA, ML (...|        [CO]|         []|
#     LNK|[TW, DH, YV, CO, ...|        [AA]|         []|
#     BFI|                  []|        [AS]|       [CO]|
#     PIR|                [9E]|          []|       [CO]|
#     ABQ|[PS, EV, PA (1), ...|          []|       [TZ]|
#     BWI|[EA, YV, OO, XE, ...|          []|       [TZ]|
#     TPA|[HP, EV, 9E, PI, ...|          []|       [TZ]|
#     ABI|[XE, OO, MQ, AA, EV]|          []|       [US]|
#     STX|[MQ, CO, AA, ML (...|        [EV]|         []|
#     PIH|            [OO, EV]|    [OH, CO]|         []|
#     YKM|        [PS, OO, US]|          []|       [AA]|
#     CAE|[XE, DH, DL, YV, ...|        [OO]|         []|
#     SPS|                [MQ]|        [OO]|         []|
#     PUB|        [OO, TW, HP]|          []|       [XE]|
#     GUM|                [CO]|        [UA]|         []|
#     BQN|        [AA, B6, CO]|        [EV]|         []|
#     ACY|    [US, OH, DH, EV]|        [AA]|       [MQ]|
#     ROW|                [MQ]|        [OO]|         []|
#     EAU|            [9E, NW]|        [OO]|         []|
#     BGR|[DH, DL, OH, MQ, ...|        [AA]|         []|
#     AGS|[CO, PI, YV, EV, ...|        [9E]|         []|
#     GGG|                [MQ]|        [AA]|         []|
#     JFK|[NW, CO, OH, XE, ...|        [TZ]|         []|
#     GNV|[EA, DL, EV, YV, ...|          []|       [OH]|
#     MSO|[CO, NW, EV, OO, ...|        [F9]|         []|
#     PHL|[F9, PI, YV, US, ...|        [B6]|         []|
# +-------+--------------------+------------+-----------+
#
# </div>

# %%
# %python

us_carrier_df\
  .groupBy('Origin', 'Dest')\
  .pivot('UniqueCarrier', ['UA', 'TW', 'DL', 'US'])\
  .count()\
  .orderBy('Origin', 'Dest')\
  .show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+----+----+----+----+
# Origin|Dest|  UA|  TW|  DL|  US|
# +------+----+----+----+----+----+
#    ABE| ALB|null|null|null|null|
#    ABE| ATL|null|null|7755|null|
#    ABE| AVP|null|null|null| 777|
#    ABE| AZO|null|null|null|null|
#    ABE| BDL|null|null|null|null|
#    ABE| BHM|null|null|null|null|
#    ABE| BWI|null| 597|null|1838|
#    ABE| CLE|null|null|null|null|
#    ABE| CLT|null|null|null|7158|
#    ABE| CVG|null|null|2239|null|
#    ABE| DCA|null| 395|null|null|
#    ABE| DTW|null|null|null|null|
#    ABE| FWA|null|null|null|null|
#    ABE| GRR|null|null|null|null|
#    ABE| HPN|  98|null|null|null|
#    ABE| IAD|null|null|null|null|
#    ABE| IND|null|null|null|null|
#    ABE| JFK|null|null|null|null|
#    ABE| LGA|  86| 116|null|null|
#    ABE| MCO|null|null| 884| 984|
# +------+----+----+----+----+----+
# only showing top 20 rows
#
# </div>

# %%
# %python

us_carrier_df.\
  filter((col('Origin') == 'ABE') & (col('Dest') == 'ATL'))\
  .select('UniqueCarrier')\
  .distinct()\
  .show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# UniqueCarrier|
# +-------------+
#            EA|
#            EV|
#            DL|
#            OH|
# +-------------+
#
# </div>

# %%
# %python

origin_df = us_carrier_df\
  .select(col('Origin').alias('id'))\
  .distinct()
dest_df = us_carrier_df\
  .select(col('Dest').alias('id'))\
  .distinct()

# 정점(vertice)을 가리키는 DataFrame에는 'id' column이 있어야 함.
vertice_df = origin_df\
  .union(dest_df)\
  .distinct()

vertice_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+
#  id|
# +---+
# BGM|
# DLG|
# PSE|
# INL|
# MSY|
# GEG|
# BUR|
# SNA|
# GTF|
# GRB|
# IDA|
# GRR|
# LWB|
# PVU|
# EUG|
# PSG|
# MYR|
# GSO|
# PVD|
# ISO|
# +---+
# only showing top 20 rows
#
# </div>

# %%
# %python

# 간선(edge)을 가리키는 DataFrame에는 'src', 'dst' column이 있어야 함.
edge_df = us_carrier_df\
  .select(col('Origin').alias('src'), col('Dest').alias('dst'))\
  .distinct()

edge_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---+
# src|dst|
# +---+---+
# SNA|PHX|
# ORD|PDX|
# PHL|MCO|
# ROC|CLE|
# ATL|GSP|
# GRR|PIT|
# JFK|ORD|
# STL|IND|
# TPA|CVG|
# MYR|CLT|
# BOS|CVG|
# WRG|PSG|
# DTW|MKE|
# JFK|BTV|
# FAT|LAX|
# CHS|ATL|
# SMF|PHX|
# BPT|DFW|
# IND|TPA|
# ISP|PVD|
# +---+---+
# only showing top 20 rows
#
# </div>

# %%
# %python

from graphframes import *

gf = GraphFrame(vertice_df, edge_df)

# print(gf)
# GraphFrame(v:[id: string], e:[src: string, dst: string])

pg_results_df = gf.pageRank(resetProbability=0.15, maxIter=10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python

display(pg_results_df.vertices.orderBy(desc('pagerank')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>pagerank</th></tr></thead><tbody><tr><td>ATL</td><td>8.569511327329835</td></tr><tr><td>SLC</td><td>6.837090454041103</td></tr><tr><td>DFW</td><td>6.818256025766324</td></tr><tr><td>ORD</td><td>6.5036102495416035</td></tr><tr><td>MSP</td><td>5.888771938630684</td></tr><tr><td>DEN</td><td>5.620870225568939</td></tr><tr><td>IAH</td><td>5.365047285685108</td></tr><tr><td>CVG</td><td>4.762090722016809</td></tr><tr><td>LAX</td><td>4.419828105868707</td></tr><tr><td>DTW</td><td>4.351968303170751</td></tr><tr><td>PHX</td><td>3.9887241926327044</td></tr><tr><td>EWR</td><td>3.8706148405924345</td></tr><tr><td>LAS</td><td>3.7845565655808064</td></tr><tr><td>PIT</td><td>3.6859756780321424</td></tr><tr><td>CLT</td><td>3.5622071293811732</td></tr><tr><td>IAD</td><td>3.5370668469935884</td></tr><tr><td>STL</td><td>3.408897994885045</td></tr><tr><td>LGA</td><td>3.316611178235266</td></tr><tr><td>MCO</td><td>3.313881705351373</td></tr><tr><td>ANC</td><td>3.1797502392580648</td></tr><tr><td>JFK</td><td>3.139749553760309</td></tr><tr><td>SFO</td><td>3.0853403118610125</td></tr><tr><td>CLE</td><td>3.0487573107675603</td></tr><tr><td>BWI</td><td>3.017476002584397</td></tr><tr><td>MEM</td><td>3.011272978699775</td></tr><tr><td>PHL</td><td>2.7074028615970183</td></tr><tr><td>COS</td><td>2.602923881645847</td></tr><tr><td>SEA</td><td>2.552579333965958</td></tr><tr><td>DCA</td><td>2.548945357352733</td></tr><tr><td>TWF</td><td>2.5423895799797953</td></tr><tr><td>AUS</td><td>2.5134642107191585</td></tr><tr><td>GJT</td><td>2.478630374136725</td></tr><tr><td>BNA</td><td>2.4757840438623457</td></tr><tr><td>TPA</td><td>2.464209059282938</td></tr><tr><td>BOS</td><td>2.4415858044280134</td></tr><tr><td>RDU</td><td>2.43292817280037</td></tr><tr><td>MDW</td><td>2.429462401062066</td></tr><tr><td>PIH</td><td>2.3729073086779695</td></tr><tr><td>FLL</td><td>2.348477211344351</td></tr><tr><td>MIA</td><td>2.322452063234601</td></tr><tr><td>MKE</td><td>2.2648649383642923</td></tr><tr><td>MCI</td><td>2.233544974886841</td></tr><tr><td>SAN</td><td>2.189244323197513</td></tr><tr><td>IND</td><td>2.0230525538909543</td></tr><tr><td>IDA</td><td>2.013232543137067</td></tr><tr><td>SAT</td><td>1.8285981879410578</td></tr><tr><td>ONT</td><td>1.8258432258277113</td></tr><tr><td>ABQ</td><td>1.8249640011706254</td></tr><tr><td>DAY</td><td>1.7993636482769815</td></tr><tr><td>SMF</td><td>1.7983226363393523</td></tr><tr><td>PDX</td><td>1.7848814742254673</td></tr><tr><td>MSY</td><td>1.7838099450508775</td></tr><tr><td>HOU</td><td>1.778951218927364</td></tr><tr><td>SJC</td><td>1.744994457225727</td></tr><tr><td>BDL</td><td>1.7319738434640484</td></tr><tr><td>JAX</td><td>1.7124234553271014</td></tr><tr><td>CMH</td><td>1.691069422617866</td></tr><tr><td>RSW</td><td>1.666771903673773</td></tr><tr><td>OAK</td><td>1.6662720018034491</td></tr><tr><td>SDF</td><td>1.6186912492672416</td></tr><tr><td>BHM</td><td>1.5893011634193936</td></tr><tr><td>SNA</td><td>1.5200841402597332</td></tr><tr><td>GUM</td><td>1.5051405229070414</td></tr><tr><td>TUS</td><td>1.4562102335761264</td></tr><tr><td>GRR</td><td>1.4394560293373844</td></tr><tr><td>PBI</td><td>1.4330459376594815</td></tr><tr><td>MSN</td><td>1.432098932812659</td></tr><tr><td>HNL</td><td>1.426020414250614</td></tr><tr><td>GSO</td><td>1.4004499857848682</td></tr><tr><td>LEX</td><td>1.3808732263945698</td></tr><tr><td>BOI</td><td>1.3696191442026409</td></tr><tr><td>OKC</td><td>1.3633941920597505</td></tr><tr><td>RNO</td><td>1.350624206306269</td></tr><tr><td>TUL</td><td>1.3194433339276697</td></tr><tr><td>SHV</td><td>1.3177705258816002</td></tr><tr><td>PSP</td><td>1.3069542007141781</td></tr><tr><td>OMA</td><td>1.302845535182399</td></tr><tr><td>SJU</td><td>1.2989080968489153</td></tr><tr><td>OGG</td><td>1.2571830975052467</td></tr><tr><td>ALB</td><td>1.2552159925647495</td></tr><tr><td>FAT</td><td>1.25325027194 ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
              {"a" : [4 ,5, 6],
               "b" : [7, 8, 9],
               "c" : [10, 11, 12]},
            index = [1, 2, 3])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df.loc[3,"a"]
# Out:
# 6

# %%
df.loc[[1,3],["a","b"]]
# Out:
#    a  b
# 1  4  7
# 3  6  9

# %%
df = pd.DataFrame( 
        [[4, 7, 10], 
         [5, 8, 11],
         [6, 9, 12]],
         index=[1, 2, 3],
         columns=['a', 'b', 'c'])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.DataFrame(
              {"a" : [4 ,5, 6, 6, np.nan],
               "b" : [7, 8, 9, 9, np.nan],
               "c" : [10, 11, np.nan, 12, 12]},
    index = pd.MultiIndex.from_tuples(
              [('d',1),('d',2),('e',2),('g',2),('t',3)],
                 names=['n','v']))

df
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  9.0   NaN
# g 2  6.0  9.0  12.0
# t 3  NaN  NaN  12.0

# %%
df[df.a > 4]
# Out:
#      a  b   c
# n v
# d 2  5  8  11
# e 2  6  9  12

# %%
df.drop_duplicates()
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
# g 2  6  9  12

# %%
df_dup = df.drop_duplicates()
df_dup
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
df.head(2)
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
# g 2  6  9  12

# %%
df[df.b != 7]
# Out:
#      a  b   c
# n v
# d 2  5  8  11
# e 2  6  9  12
# g 2  6  9  12

# %%
df.b.isin([8])
# Out:
# n  v
# d  1    False
#    2     True
# e  2    False
# g  2    False
# Name: b, dtype: bool

# %%
pd.notnull(df)
# Out:
#          a      b      c
# n v
# d 1   True   True   True
#   2   True   True   True
# e 2   True   True  False
# g 2   True   True   True
# t 3  False  False   True

# %% [markdown]
# &,|,~,^,df.any(),df.all()

# %%
df.any()
# Out:
# a    True
# b    True
# c    True
# dtype: bool

# %%
df
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  9.0   NaN
# g 2  6.0  9.0  12.0
# t 3  NaN  NaN  12.0

# %%
df.sample(frac=0.6)
# Out:
#        a    b     c
# n v
# e 2  6.0  9.0   NaN
# d 1  4.0  7.0  10.0
# t 3  NaN  NaN  12.0

# %%
df.iloc[:4]
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  9.0   NaN
# g 2  6.0  9.0  12.0

# %%
df.nlargest(3,'a')
# Out:
#        a    b     c
# n v
# e 2  6.0  9.0   NaN
# g 2  6.0  9.0  12.0
# d 2  5.0  8.0  11.0

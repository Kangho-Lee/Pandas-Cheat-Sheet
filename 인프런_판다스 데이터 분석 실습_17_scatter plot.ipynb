# %% [markdown]
# # scatter plot
# - 산점도
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline
# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.head(5)
# Out:
#           a         b         c         d
# 0  0.160626  0.105957  0.555636  0.760934
# 1  0.801250  0.897388  0.153517  0.984451
# 2  0.364120  0.677726  0.151736  0.407009
# 3  0.971435  0.492813  0.038502  0.889256
# 4  0.921286  0.971645  0.095541  0.996207

# %%
df.plot.scatter(x='a', y='b', grid=True);

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1', grid=True)
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax, grid=True)

# %%
df.plot.scatter(x='a', y='b', c='c', s=80)

# %%
 df.plot.scatter(x='a', y='b', s=df['c'] * 200)

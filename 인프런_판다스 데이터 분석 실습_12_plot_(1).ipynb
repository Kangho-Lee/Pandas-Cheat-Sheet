# %% [markdown]
# ## 파이썬 판다스로 Series와 DataFrame 데이터 시각화 하기

# %% [markdown]
# #### https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## plot
# ### kind : str
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot

# %%
df = pd.DataFrame()

# %%
df.plot?

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))

# %%
ts.plot()

# %%
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))
df.plot()

# %%
df = df.cumsum()
df.plot()

# %%
df
# Out:
#                    A         B          C          D
# 2000-01-01  0.448442 -0.927378   0.734520   0.003013
# 2000-01-02  0.882120 -0.806772   2.623509  -1.026746
# 2000-01-03  1.477386 -2.838545   2.273983  -1.618995
# 2000-01-04  0.863361 -2.302496   2.658917  -2.353667
# 2000-01-05  2.538762 -1.612318   3.060552  -2.753108
# ...              ...       ...        ...        ...
# 2002-09-22 -4.776698 -4.530701  33.391842  12.806125
# 2002-09-23 -4.956163 -4.350526  33.257085  12.631530
# 2002-09-24 -4.600048 -4.132663  33.690927  11.675083
# 2002-09-25 -5.540982 -4.115802  33.292471  11.172198
# 2002-09-26 -4.294744 -5.670159  32.674296  12.448256
#
# [1000 rows x 4 columns]

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df3.head()
# Out:
#           B         C
# 0  0.253616 -0.288751
# 1  1.701267 -1.180255
# 2  2.335991  0.064438
# 3  1.769551  0.911979
# 4  3.554133  0.129793

# %%
df3['A'] = pd.Series(list(range(len(df))))
df3.head()
# Out:
#           B         C  A
# 0  0.253616 -0.288751  0
# 1  1.701267 -1.180255  1
# 2  2.335991  0.064438  2
# 3  1.769551  0.911979  3
# 4  3.554133  0.129793  4

# %%
df3.plot(x='A', y='B')

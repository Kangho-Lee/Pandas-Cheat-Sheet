# %% [markdown]
# - 튜토리얼 영상링크 : https://youtu.be/PtSofOihtZs # Scatter Matrix Plot
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#plotting-tools

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline
# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df.head(5)
# Out:
#           a         b         c         d
# 0  0.653597 -0.568594  0.684858  0.177885
# 1  0.843134  0.402073  1.893757 -0.030638
# 2 -0.064245  1.874427  0.193245 -0.090464
# 3 -0.217249  0.362568 -0.778019 -1.711200
# 4 -0.576360 -0.512293 -1.035443 -1.941797

# %%
# kde - 커널밀도함수
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x131504040>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1314f9370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1315ca940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1315fff70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x131628a00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13165f280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13166c190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131695a30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1316e8b80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13171e400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131748c40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13177d4c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1317a8d00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1317dc580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131806dc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13183a640>]],
#       dtype=object)
